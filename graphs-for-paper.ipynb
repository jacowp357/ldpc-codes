# %%
# %matplotlib notebook
from matplotlib.pyplot import *
from jupyterplot import ProgressPlot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib.ticker import FormatStrFormatter
import scipy.stats as ss
import graphviz as gv
import scipy.stats as stats
import scipy.special as special
import itertools
import time, random
import math
import matplotlib.animation as animation
pd.options.display.max_columns = None
plt.rcParams.update({'font.size': 14})
plt.rcParams["font.family"] = "Times New Roman"

# %%
mu = -2
mu1 = 2
variance = 3
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma), color='black')
x = np.linspace(mu1 - 3*sigma, mu1 + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu1, sigma), color='black')
plt.axvline(x=2, linestyle='--', color='black', alpha=0.5)
plt.axvline(x=-2, linestyle='--', color='black', alpha=0.5)

ax = plt.gca()
ax.axes.get_yaxis().set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

labels = ['', '', '', r'-$\sqrt{E_b}$', r'$\tau$', r'$\sqrt{E_b}$', '']

ax.set_xticklabels(labels)

x_pos = 2.5
y_pos = 0.25
plt.text(x_pos, y_pos, r"$p(r|b_{1})$")
x_pos = -1.5
y_pos = 0.25
plt.text(x_pos, y_pos, r"$p(r|b_{0})$")
plt.savefig("foo.pdf", bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s0 = np.random.normal(-1, 0.2, 10)
s1 = np.random.normal(1, 0.2, 10)
s = np.concatenate((s0, s1))
random.shuffle(s)

s0 = np.random.normal(-1, 0.08, 10)
s1 = np.random.normal(1, 0.08, 10)
t = np.concatenate((s0, s1))
random.shuffle(t)

s = np.concatenate((s, t))

plt.rcParams.update({'font.size': 14})

fig, ax = plt.subplots()
fig.set_size_inches(10, 4)

plt.scatter(range(1, 41), s, c='black')
plt.axhline(-1, color='black', linestyle=':', alpha=0.5)
plt.axhline(1, color='black', linestyle=':', alpha=0.5)
plt.axvline(6, color='black', linestyle='--')
plt.axvline(12, color='black', linestyle='--')
plt.axvline(18, color='black', linestyle='--')
# plt.axvline(24, color='black', linestyle='--')
# plt.axvline(30, color='black', linestyle='--')

positions = range(1, 30)
labels = [r"$t_{{{0}}}$".format(i) for i in range(1, 30)]
plt.xticks(positions, labels, rotation=0)

plt.text(2.25,0.06, r'$p=1$')

plt.annotate('', xy=(0,0), xytext=(6, 0),
              arrowprops=dict( arrowstyle="<->",shrinkA=0))

plt.text(8.25,0.06, r'$p=2$')

plt.annotate('', xy=(6,0), xytext=(12, 0),
              arrowprops=dict( arrowstyle="<->",shrinkA=0))

plt.text(14.25,0.06, r'$p=3$')

plt.annotate('', xy=(12,0), xytext=(18, 0),
              arrowprops=dict( arrowstyle="<->",shrinkA=0))

plt.text(20.25,0.06, '. . .')

plt.xlim([0, 23])
plt.xlabel("Bits received")
plt.ylabel(r"Received signal values $r_{t}$")
subplots_adjust(bottom=0.14)
plt.savefig("bits-received.pdf", bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
